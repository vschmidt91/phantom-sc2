# %%
import lzma
import pickle
import sys

from sc2.bot_ai import BotAI

sys.path.append("../ares-sc2")  # required to import sc2_helper
sys.path.append("../ares-sc2/src")  # required to import ares
sys.path.append("phantom")

# %%
with lzma.open("../resources/maps/Abyssal Reef AIE.xz", "rb") as f:
    export = pickle.load(f)
bot: BotAI = await export.create_bot()
bot
# Out:
# 2025-03-31 22:14:53.161 | DEBUG    | sc2.protocol:__request:38 - Sending request: query {
#   abilities {
#     unit_tag: 8791588867
#   }
#   abilities {
#     unit_tag: 8794210307
#   }
#   abilities {
#     unit_tag: 8795848707
#   }
#   abilities {
#     unit_tag: 8796897283
#   }
#   abilities {
#     unit_tag: 8797683715
#   }
#   abilities {
#     unit_tag: 8798732291
#   }
#   abilities {
#     unit_tag: 8799518723
#   }
#   abilities {
#     unit_tag: 8800567299
#   }
#   abilities {
#     unit_tag: 8801353730
#   }
#   abilities {
#     unit_tag: 8802009090
#   }
#   abilities {
#     unit_tag: 8802402306
#   }
#   abilities {
#     unit_tag: 8802795522
#   }
#   abilities {
#     unit_tag: 8803188738
#   }
#   abilities {
#     unit_tag: 8803581954
#   }
#   abilities {
#     unit_tag: 8803975170
#   }
#   abilities {
#     unit_tag: 8804368386
#   }
#   abilities {
#     unit_tag: 8804761602
#   }
#   abilities {
#     unit_tag: 8805679106
#   }
#   abilities {
#     unit_tag: 8806072322
#   }
#   abilities {
#     unit_tag: 8806465538
#   }
#   abilities {
#     unit_tag: 8806858754
#   }
#   abilities {
#     unit_tag: 8807514114
#   }
#   abilities {
#     unit_tag: 8807907330
#   }
#   abilities {
#     unit_tag: 8808300546
#   }
#   abilities {
#     unit_tag: 8808693762
#   }
#   abilities {
#     unit_tag: 8809349122
#   }
#   abilities {
#     unit_tag: 8809742338
#   }
#   abilities {
#     unit_tag: 8810135554
#   }
#   abilities {
#     unit_tag: 8810528770
#   }
#   abilities {
#     unit_tag: 8811249666
#   }
#   abilities {
#     unit_tag: 8811642882
#   }
#   abilities {
#     unit_tag: 8812036098
#   }
#   abilities {
#     unit_tag: 8812429314
#   }
#   abilities {
#     unit_tag: 8815312897
#   }
#   abilities {
#     unit_tag: 8815443969
#   }
#   abilities {
#     unit_tag: 8815575041
#   }
#   abilities {
#     unit_tag: 8815706113
#   }
#   abilities {
#     unit_tag: 8815837185
#   }
#   abilities {
#     unit_tag: 8815968257
#   }
#   abilities {
#     unit_tag: 8816099329
#   }
#   abilities {
#     unit_tag: 8816230401
#   }
#   abilities {
#     unit_tag: 8816361473
#   }
#   abilities {
#     unit_tag: 8816492545
#   }
#   abilities {
#     unit_tag: 8816623617
#   }
#   abilities {
#     unit_tag: 8816754689
#   }
#   abilities {
#     unit_tag: 8816885761
#   }
#   abilities {
#     unit_tag: 8817016833
#   }
#   abilities {
#     unit_tag: 8817147905
#   }
#   abilities {
#     unit_tag: 8817278977
#   }
#   abilities {
#     unit_tag: 8817410049
#   }
#   abilities {
#     unit_tag: 8817541121
#   }
#   abilities {
#     unit_tag: 8817672193
#   }
#   abilities {
#     unit_tag: 8817803265
#   }
#   abilities {
#     unit_tag: 8817934337
#   }
#   abilities {
#     unit_tag: 8818065409
#   }
#   abilities {
#     unit_tag: 8818196481
#   }
#   abilities {
#     unit_tag: 8818327553
#   }
#   abilities {
#     unit_tag: 8818458625
#   }
#   abilities {
#     unit_tag: 8818589697
#   }
#   abilities {
#     unit_tag: 8818720769
#   }
#   abilities {
#     unit_tag: 8818851841
#   }
#   abilities {
#     unit_tag: 8818982913
#   }
#   abilities {
#     unit_tag: 8819113985
#   }
#   abilities {
#     unit_tag: 8819245057
#   }
#   abilities {
#     unit_tag: 8819376129
#   }
#   abilities {
#     unit_tag: 8819507201
#   }
#   abilities {
#     unit_tag: 8819638273
#   }
#   abilities {
#     unit_tag: 8819769345
#   }
#   abilities {
#     unit_tag: 8819900417
#   }
#   abilities {
#     unit_tag: 8820031489
#   }
#   abilities {
#     unit_tag: 8820162561
#   }
#   abilities {
#     unit_tag: 8820293633
#   }
#   abilities {
#     unit_tag: 8820424705
#   }
#   abilities {
#     unit_tag: 8820555777
#   }
#   abilities {
#     unit_tag: 8820686849
#   }
#   abilities {
#     unit_tag: 8820817921
#   }
#   abilities {
#     unit_tag: 8820948993
#   }
#   abilities {
#     unit_tag: 8821080065
#   }
#   abilities {
#     unit_tag: 8821211137
#   }
#   abilities {
#     unit_tag: 8821342209
#   }
#   abilities {
#     unit_tag: 8821473281
#   }
#   abilities {
#     unit_tag: 8821604353
#   }
#   abilities {
#     unit_tag: 8821735425
#   }
#   abilities {
#     unit_tag: 8821866497
#   }
#   abilities {
#     unit_tag: 8821997569
#   }
#   abilities {
#     unit_tag: 8822128641
#   }
#   abilities {
#     unit_tag: 8822194177
#   }
#   abilities {
#     unit_tag: 8822259713
#   }
#   abilities {
#     unit_tag: 8822325249
#   }
#   abilities {
#     unit_tag: 8822390785
#   }
#   abilities {
#     unit_tag: 8822456321
#   }
#   abilities {
#     unit_tag: 8822587393
#   }
#   abilities {
#     unit_tag: 8822718465
#   }
#   abilities {
#     unit_tag: 8822849537
#   }
#   abilities {
#     unit_tag: 8822980609
#   }
#   abilities {
#     unit_tag: 8823046145
#   }
#   abilities {
#     unit_tag: 8823177217
#   }
#   abilities {
#     unit_tag: 8823308289
#   }
#   abilities {
#     unit_tag: 8823439361
#   }
#   abilities {
#     unit_tag: 8823570433
#   }
#   abilities {
#     unit_tag: 8823701505
#   }
#   abilities {
#     unit_tag: 8823832577
#   }
#   abilities {
#     unit_tag: 8823963649
#   }
#   abilities {
#     unit_tag: 8824094721
#   }
#   abilities {
#     unit_tag: 8824225793
#   }
#   abilities {
#     unit_tag: 8824356865
#   }
#   abilities {
#     unit_tag: 8824487937
#   }
#   abilities {
#     unit_tag: 8824619009
#   }
#   abilities {
#     unit_tag: 8824750081
#   }
#   abilities {
#     unit_tag: 8824881153
#   }
#   abilities {
#     unit_tag: 8825012225
#   }
#   abilities {
#     unit_tag: 8825143297
#   }
#   abilities {
#     unit_tag: 8825274369
#   }
#   abilities {
#     unit_tag: 8825405441
#   }
#   abilities {
#     unit_tag: 8825536513
#   }
#   abilities {
#     unit_tag: 8825667585
#   }
#   abilities {
#     unit_tag: 8825798657
#   }
#   abilities {
#     unit_tag: 8825929729
#   }
#   abilities {
#     unit_tag: 8826060801
#   }
#   abilities {
#     unit_tag: 8826191873
#   }
#   abilities {
#     unit_tag: 8826322945
#   }
#   abilities {
#     unit_tag: 8826454017
#   }
#   abilities {
#     unit_tag: 8826585089
#   }
#   abilities {
#     unit_tag: 8826716161
#   }
#   abilities {
#     unit_tag: 8826847233
#   }
#   abilities {
#     unit_tag: 8826978305
#   }
#   abilities {
#     unit_tag: 8827109377
#   }
#   abilities {
#     unit_tag: 8827240449
#   }
#   abilities {
#     unit_tag: 8827371521
#   }
#   abilities {
#     unit_tag: 8827502593
#   }
#   abilities {
#     unit_tag: 8827633665
#   }
#   abilities {
#     unit_tag: 8827764737
#   }
#   abilities {
#     unit_tag: 8827895809
#   }
#   abilities {
#     unit_tag: 8828026881
#   }
#   abilities {
#     unit_tag: 8828157953
#   }
#   abilities {
#     unit_tag: 8828289025
#   }
#   abilities {
#     unit_tag: 8828420097
#   }
#   abilities {
#     unit_tag: 8828551169
#   }
#   abilities {
#     unit_tag: 8828682241
#   }
#   abilities {
#     unit_tag: 8828813313
#   }
#   abilities {
#     unit_tag: 8828944385
#   }
#   abilities {
#     unit_tag: 8829075457
#   }
#   abilities {
#     unit_tag: 8829206529
#   }
#   abilities {
#     unit_tag: 8829337601
#   }
#   abilities {
#     unit_tag: 8829468673
#   }
#   abilities {
#     unit_tag: 8829599745
#   }
#   abilities {
#     unit_tag: 8829730817
#   }
#   abilities {
#     unit_tag: 8829861889
#   }
#   abilities {
#     unit_tag: 8829992961
#   }
#   abilities {
#     unit_tag: 8830124033
#   }
#   abilities {
#     unit_tag: 8830255105
#   }
#   abilities {
#     unit_tag: 8830386177
#   }
#   abilities {
#     unit_tag: 8830517249
#   }
#   abilities {
#     unit_tag: 8830648321
#   }
#   abilities {
#     unit_tag: 8830779393
#   }
#   abilities {
#     unit_tag: 8830910465
#   }
#   abilities {
#     unit_tag: 4295753729
#   }
#   abilities {
#     unit_tag: 4296015873
#   }
#   abilities {
#     unit_tag: 4296278017
#   }
#   abilities {
#     unit_tag: 4296802305
#   }
#   abilities {
#     unit_tag: 4297064449
#   }
#   abilities {
#     unit_tag: 4297326593
#   }
#   abilities {
#     unit_tag: 4346871809
#   }
#   abilities {
#     unit_tag: 4348182529
#   }
#   abilities {
#     unit_tag: 4348444673
#   }
#   abilities {
#     unit_tag: 4348706817
#   }
#   abilities {
#     unit_tag: 4348968961
#   }
#   abilities {
#     unit_tag: 4349493249
#   }
#   abilities {
#     unit_tag: 4350017537
#   }
#   abilities {
#     unit_tag: 4350279681
#   }
#   abilities {
#     unit_tag: 4350541825
#   }
#   abilities {
#     unit_tag: 4349755393
#   }
#   abilities {
#     unit_tag: 4349231105
#   }
#   abilities {
#     unit_tag: 4347920385
#   }
#   abilities {
#     unit_tag: 4347658241
#   }
#   abilities {
#     unit_tag: 4347396097
#   }
#   abilities {
#     unit_tag: 4347133953
#   }
#   abilities {
#     unit_tag: 4346609665
#   }
#   abilities {
#     unit_tag: 4346347521
#   }
#   abilities {
#     unit_tag: 4296540161
#   }
#   abilities {
#     unit_tag: 4295491585
#   }
#   abilities {
#     unit_tag: 4295229441
#   }
#   abilities {
#     unit_tag: 4294967297
#   }
#   ignore_resource_requirements: false
# }

# %%
bot.units
# Out:
# [Unit(name='Larva', tag=4346871809),
#  Unit(name='Drone', tag=4348182529),
#  Unit(name='Drone', tag=4348444673),
#  Unit(name='Drone', tag=4348706817),
#  Unit(name='Drone', tag=4348968961),
#  Unit(name='Drone', tag=4349493249),
#  Unit(name='Drone', tag=4350017537),
#  Unit(name='Drone', tag=4350279681),
#  Unit(name='Overlord', tag=4350541825),
#  Unit(name='Drone', tag=4349755393),
#  Unit(name='Drone', tag=4349231105),
#  Unit(name='Drone', tag=4347920385),
#  Unit(name='Drone', tag=4347658241),
#  Unit(name='Drone', tag=4347396097),
#  Unit(name='Larva', tag=4347133953),
#  Unit(name='Larva', tag=4346609665)]

# %%
unit = bot.units[0]

# %%
# %%timeit
unit.tag
# Out:
# 36.4 ns ± 5.85 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%timeit
unit.is_flying
# Out:
# 248 ns ± 13.1 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%timeit
unit.type_id
# Out:
# 406 ns ± 195 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
